# %%
# coding: utf-8
import sys
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import time
from numpy import eye
from LoadMZML import LoadMZML
from OptimalMz import OptimalMz
from OptimalMzV2 import OptimalMzV2
from PlotImage import PlotImage
from TemplateOverlay import TemplateOverlay
% matplotlib inline

# %% [markdown]
# # Parameters

# %%
class Parameters2:
    def __init__(self):
        #  self.filename = '/Users/simon/Dropbox/MS_Ink_Data/ALphabet/abcdefgh_1.mzML'
        self.filename = '..\\data\\AA_Array_2.mzML'
        self.lines = 6
        self.widthInMM = 50
        self.heightInMM = 15
        self.downMotionInMM = 3

# %%
param = Parameters2()
loadMZML = LoadMZML(param, 'positive')
plotImage = PlotImage(loadMZML, param)

# %% [markdown]
# # Cell 1

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=0, x_stop_mm=6.25, y_start_mm=0, y_stop_mm=4,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
for i, j in optimalMz.getN(5):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 112.80s
# i - i1:
# [ 100.44073342   97.83074379   64.3838155    63.4495871    57.81011427]
#
# mz:
# [(101.0, 101.25), (185.0, 185.25), (135.0, 135.25), (139.0, 139.25), (95.0, 95.25)]
#
# i:
# [ 710.51020921  832.0411837   275.9753511   569.72729278  707.5169622 ]
# i1:
# [ 610.06947579  734.21043991  211.59153559  506.27770568  649.70684793]
# c:
# [1087 2198 2164 2217 1811]
# c1:
# [22070 45452 47619 40697 40229]
# range:
# 0.25
# 100%
# 8.85s
# 100%
# 8.76s
# 100%
# 9.58s
# 100%
# 9.07s
# 100%
# 9.11s

# %% [markdown]
# # Cell 2

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=6.25, x_stop_mm=12.5, y_start_mm=0, y_stop_mm=4,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
# Out:
# 100%
# 86.33s
# i - i1:
# [ 266.48188859  221.31717198   82.75928641   74.81120479   65.9077985 ]
#
# mz:
# [(104.0, 104.25), (150.0, 150.25), (194.0, 194.25), (133.0, 133.25), (139.0, 139.25)]
#
# i:
# [ 348.26805991  511.51431517  134.25880367  256.60847948  572.31652566]
# i1:
# [  81.78617132  290.19714319   51.49951725  181.79727469  506.40872715]
# c:
# [ 467 1469  159 2452 2049]
# c1:
# [ 1228 28952   153 47580 40865]
# range:
# 0.25

# %%
plotImage.plotImshowII((104.0,104.25))
# Out:
# 100%
# 9.61s

# %%
plotImage.plotImshowII((150.0, 150.25))
# Out:
# 100%
# 9.75s

# %% [markdown]
# # Cell 3

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=12.5, x_stop_mm=18.75, y_start_mm=0, y_stop_mm=4,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
# Out:
# 100%
# 86.44s
# i - i1:
# [ 100.38529213   75.62717423   66.99679084   50.72109985   38.90457907]
#
# mz:
# [(175.0, 175.25), (139.0, 139.25), (70.0, 70.25), (158.75, 159.0), (121.0, 121.25)]
#
# i:
# [  182.49762115   581.68109605  1037.73884078    50.72109985   414.30643543]
# i1:
# [  82.11232902  506.05392182  970.74204994    0.          375.40185636]
# c:
# [1876 1987 1759   10 2427]
# c1:
# [38670 40927 37833     3 54196]
# range:
# 0.25

# %%
plotImage.plotImshowII((175.0,175.25))
# Out:
# 100%
# 9.17s

# %% [markdown]
# # Cell 9

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=0, x_stop_mm=6.25, y_start_mm=5, y_stop_mm=10,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
# Out:
# 100%
# 86.08s
# i - i1:
# [ 664.85764112  243.03851678  225.97098991  147.40117492  100.28163318]
#
# mz:
# [(132.0, 132.25), (199.0, 199.25), (112.0, 112.25), (86.0, 86.25), (104.75, 105.0)]
#
# i:
# [  770.52331809  6733.92060393  6118.69158431   446.82191861   242.73284308]
# i1:
# [  105.66567697  6490.88208714  5892.7205944    299.42074369   142.4512099 ]
# c:
# [ 572 4899 2027 2287  572]
# c1:
# [ 5209 68681 30550 26369  8961]
# range:
# 0.25

# %%
plotImage.plotImshowII((132.0,132.25))
# Out:
# 100%
# 12.13s

# %% [markdown]
# # Cell 12

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=18.75, x_stop_mm=25, y_start_mm=6, y_stop_mm=9,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
for i, j in optimalMz.getN(5):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 81.77s
# i - i1:
# [ 2541.52221219  2500.18646651  1322.57709518   249.27407897   183.78597455]
#
# mz:
# [(120.0, 120.25), (166.0, 166.25), (116.0, 116.25), (70.0, 70.25), (103.0, 103.25)]
#
# i:
# [ 2646.12011772  2603.43563882  1508.7030654   1211.17494658   327.81152088]
# i1:
# [ 104.59790553  103.24917231  186.12597021  961.9008676   144.02554633]
# c:
# [1121  369  285 1877 1887]
# c1:
# [18094   894  5202 37715 33905]
# range:
# 0.25
# 100%
# 10.62s
# 100%
# 10.56s
# 100%
# 10.68s
# 100%
# 10.56s
# 100%
# 10.47s

# %% [markdown]
# # Cell 20

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=18.75, x_stop_mm=22, y_start_mm=12, y_stop_mm=15,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
for i, j in optimalMz.getN(5):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 71.89s
# i - i1:
# [ 127.97728172  113.41476214   56.5330365    54.07350431   49.56085064]
#
# mz:
# [(175.0, 175.25), (105.0, 105.25), (70.0, 70.25), (145.75, 146.0), (104.75, 105.0)]
#
# i:
# [  211.78625225  1171.27679527  1028.78375975    54.07350431   196.94780346]
# i1:
# [   83.80897053  1057.86203312   972.25072325     0.           147.38695282]
# c:
# [ 934 1099 1028   14  208]
# c1:
# [39612 42337 38564     0  9325]
# range:
# 0.25
# 100%
# 10.60s
# 100%
# 10.66s
# 100%
# 11.04s
# 100%
# 11.01s
# 100%
# 7.14s

# %% [markdown]
# # Cell 21

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=25, x_stop_mm=31, y_start_mm=10, y_stop_mm=15,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
for i, j in optimalMz.getN(5):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 112.26s
# i - i1:
# [ 502.40946933  386.72782826  209.25486646   59.79366056   45.31026723]
#
# mz:
# [(110.0, 110.25), (156.0, 156.25), (124.0, 124.25), (82.0, 82.25), (118.75, 119.0)]
#
# i:
# [ 635.20918768  474.78367576  295.37918508  115.92067673   45.31026723]
# i1:
# [ 132.79971834   88.05584749   86.12431863   56.12701616    0.        ]
# c:
# [1097  262  134  778   13]
# c1:
# [17586  1120   446 14815     0]
# range:
# 0.25
# 100%
# 10.17s
# 100%
# 11.43s
# 100%
# 12.07s
# 100%
# 5.82s
# 100%
# 8.02s

# %% [markdown]
# # Cell 22

# %% [markdown]
# Not strong effect, Sensitive to x margin

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=31.25, x_stop_mm=37.5, y_start_mm=12, y_stop_mm=15,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
for i, j in optimalMz.getN(5):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 101.22s
# i - i1:
# [ 66.73899983  38.73664592  38.11676554  35.58824246  32.77018562]
#
# mz:
# [(122.0, 122.25), (196.75, 197.0), (162.25, 162.5), (159.25, 159.5), (103.75, 104.0)]
#
# i:
# [ 149.37218295   38.73664592   38.11676554   35.58824246   32.77018562]
# i1:
# [ 82.63318312   0.           0.           0.           0.        ]
# c:
# [57 13 13 13 13]
# c1:
# [4193    2    0   13    0]
# range:
# 0.25
# 100%
# 12.88s
# 100%
# 12.95s
# 100%
# 10.33s
# 100%
# 6.52s
# 100%
# 10.75s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=31.25, x_stop_mm=37.5, y_start_mm=12, y_stop_mm=15,
                         mzRangeLower=50, mzRangeHighest=200, resolution=600)
optimalMz.printN()
for i, j in optimalMz.getN(5):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 162.07s
# i - i1:
# [ 9351.04833007  5871.38404517  2893.62715559   535.72238995   259.77092461]
#
# mz:
# [(165.0, 165.25), (154.0, 154.25), (135.0, 135.25), (144.75, 145.0), (134.0, 134.25)]
#
# i:
# [ 115.35821424  102.77747557  230.76558738  111.40832652  117.27996623]
# i1:
# [  89.45503327   86.51325384  213.6435332   109.75486236   88.41653016]
# c:
# [2133  504 2171  704  163]
# c1:
# [45310  8395 47612 14960  1676]
# range:
# 0.25
# 100%
# 14.05s
# 100%
# 11.17s
# 100%
# 16.24s
# 100%
# 9.91s
# 100%
# 11.27s
