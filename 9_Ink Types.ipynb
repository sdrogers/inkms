# %%
# coding: utf-8
import sys
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import time
from numpy import eye
from LoadMZML import LoadMZML
from OptimalMz import OptimalMz
from OptimalMzV2 import OptimalMzV2
from PlotImage import PlotImage
from TemplateOverlay import TemplateOverlay
% matplotlib inline

# %% [markdown]
# # Parameters

# %%
class Parameters:
    def __init__(self):
        #  self.filename = '/Users/simon/Dropbox/MS_Ink_Data/ALphabet/abcdefgh_1.mzML'
        self.filename = '..\\data\\Block2_neg_50.mzML'
        self.lines = 6
        self.widthInMM = 70
        self.heightInMM = 10
        self.downMotionInMM = 1.66

# %%
param = Parameters()
loadMZML = LoadMZML(param)
plotImage = PlotImage(loadMZML, param)

# %%
plotImage.plotImshowII((220.14, 220.16))
# Out:
# 100%
# 12.41s

# %% [markdown]
# # Cell D

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=60, x_stop_mm=70, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=500, resolution=1000)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 73.65s
# i1 - i:
# [ -1.17610655e+08  -4.27567727e+07  -3.44803173e+07  -3.40589963e+07
#   -2.73134019e+07]
#
# mz:
# [(220.0, 220.5), (199.0, 199.5), (93.0, 93.5), (157.0, 157.5), (171.0, 171.5)]
#
# i:
# [ 4075.18726995  1947.44266528  2419.5559164   1824.67398173  1349.82854209]
# i1:
# [  675.64237551   763.04452919  1433.53065762   840.19611508   568.7538215 ]
# c:
# [ 4664  4714 12170  6602  7089]
# c1:
# [16519 22082 41767 28528 33707]
# range:
# 0.5
# 100%
# 3.29s
# 100%
# 2.85s
# 100%
# 2.80s
# 100%
# 3.32s
# 100%
# 3.02s

# %% [markdown]
# # Cell C

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=41, x_stop_mm=51, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=8000)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 72.71s
# i1 - i:
# [-4943365.97765522 -4869801.75550856 -4602518.02298777 -4244031.69397955
#  -3531380.31541197]
#
# mz:
# [(222.90000000000001, 222.95000000000002), (188.90000000000001, 188.95000000000002), (156.90000000000001, 156.95000000000002), (90.950000000000003, 91.0), (394.80000000000001, 394.85000000000002)]
#
# i:
# [ 386.7496816   383.62146668  337.86472781  354.21785653  290.76030785]
# i1:
# [ 237.5114864   238.2065019   204.8285958   227.48873073  181.76708824]
# c:
# [2897 3065 2779 3447 1704]
# c1:
# [16684 17830 16145 20084  9632]
# range:
# 0.05
# 100%
# 3.03s
# 100%
# 2.91s
# 100%
# 3.10s
# 100%
# 2.99s
# 100%
# 3.10s

# %% [markdown]
# # Cell B

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=400)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 75.81s
# i1 - i:
# [-1737748.94773262 -1708601.23155349 -1432748.80092603  -910004.86169682
#   -766028.87156757]
#
# mz:
# [(220.0, 221.0), (93.0, 94.0), (199.0, 200.0), (157.0, 158.0), (143.0, 144.0)]
#
# i:
# [ 1690.62459917  1751.4165123   1080.60235964  1106.13690605   483.59125734]
# i1:
# [ 1335.98195677  1583.92300857   911.32674517   977.16796307   403.82981715]
# c:
# [3627 7937 3918 5471 4062]
# c1:
# [18000 47634 23951 30689 23578]
# range:
# 1.0
# 100%
# 3.58s
# 100%
# 3.52s
# 100%
# 3.31s
# 100%
# 3.10s
# 100%
# 2.96s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=800)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 70.38s
# i1 - i:
# [-1663058.78121136 -1647586.55096008 -1596369.54776659  -894982.25689103
#   -735974.76794187]
#
# mz:
# [(220.0, 220.5), (93.0, 93.5), (199.0, 199.5), (157.0, 157.5), (143.0, 143.5)]
#
# i:
# [ 1723.40756537  1797.14814282  1130.20352855  1130.21070024   491.06226445]
# i1:
# [ 1363.74952445  1632.38948773   945.63079786  1006.33772351   414.43015617]
# c:
# [3557 7733 3742 5352 3997]
# c1:
# [17626 46204 23054 29778 22941]
# range:
# 0.5
# 100%
# 2.99s
# 100%
# 2.94s
# 100%
# 3.04s
# 100%
# 2.87s
# 100%
# 3.12s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=1600)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 71.79s
# i1 - i:
# [-1732576.81470933 -1525901.5907947  -1217586.25113612  -869824.62963834
#   -664853.2986494 ]
#
# mz:
# [(220.0, 220.25), (199.0, 199.25), (93.0, 93.25), (157.0, 157.25), (143.0, 143.25)]
#
# i:
# [ 1777.93011728  1134.33719571  1855.08174894  1135.62306229   496.1396919 ]
# i1:
# [ 1414.01984324   954.05581684  1717.28339549  1015.23211009   422.47173637]
# c:
# [3446 3728 7489 5326 3954]
# c1:
# [16987 22845 43894 29511 22480]
# range:
# 0.25
# 100%
# 2.91s
# 100%
# 3.05s
# 100%
# 2.92s
# 100%
# 3.08s
# 100%
# 3.10s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=4000)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 100.19s
# i1 - i:
# [-3218536.4595814  -1767955.92721024 -1521788.98417234 -1308428.3180168
#  -1201660.19307581]
#
# mz:
# [(157.09999999999999, 157.19999999999999), (220.09999999999999, 220.19999999999999), (199.09999999999999, 199.19999999999999), (143.09999999999999, 143.19999999999999), (93.0, 93.099999999999994)]
#
# i:
# [ 1727.10526087  1822.10446674  1141.75338682   717.62994913  1881.21144792]
# i1:
# [ 1354.97710044  1439.76105687   961.95790192   563.04248244  1742.27513239]
# c:
# [3449 3361 3703 2708 7384]
# c1:
# [21853 16677 22652 16772 43258]
# range:
# 0.1
# 100%
# 5.66s
# 100%
# 5.60s
# 100%
# 3.80s
# 100%
# 2.86s
# 100%
# 3.08s

# %% [markdown]
# # Cell A

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=0, x_stop_mm=10, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=1000, resolution=8000)
optimalMz.printN(10)
for i, j in optimalMz.getN(10):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 80.63s
# i1 - i:
# [-137120.61872347  -80452.46774127  -52876.49097788  -16879.81760351
#   -11742.27785841   -6736.99265923   -5778.21538791   -4922.97859941
#    -3803.09561674   -3742.33072663]
#
# mz:
# [(676.0, 676.125), (96.875, 97.0), (169.0, 169.125), (295.0, 295.125), (675.375, 675.5), (237.875, 238.0), (207.375, 207.5), (312.375, 312.5), (676.25, 676.375), (198.875, 199.0)]
#
# i:
# [ 194.91813094   40.57278482  266.48947308   73.30745521   46.4909554
#    52.91603407   40.09980974   42.54865323   33.61039135   41.48927999]
# i1:
# [ 177.21143947   30.64038139  260.24225061   71.47587778   41.39448064
#    51.98357834   38.68911263   40.79607986   32.43984791   40.78702239]
# c:
# [ 1708  2194 15452  2835   634  2538  1969   792  1199  2191]
# c1:
# [ 9625  5155 92370 15479  3882 14926 11697  4617  7249 13157]
# range:
# 0.125
# 100%
# 3.04s
# 100%
# 2.93s
# 100%
# 3.06s
# 100%
# 3.13s
# 100%
# 2.97s
# 100%
# 3.07s
# 100%
# 2.95s
# 100%
# 3.07s
# 100%
# 2.91s
# 100%
# 3.11s

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=0, x_stop_mm=10, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=1000, resolution=4000)
optimalMz.printN(10)
for i, j in optimalMz.getN(10):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 42.78s
# i1 - i:
# [-50.76940842 -45.80006841 -43.58558429 -43.49154569 -42.94576997
#  -42.82113244 -37.56749922 -37.38404496 -34.94126683 -34.21601508]
#
# mz:
# [(809.5, 809.75), (803.75, 804.0), (914.25, 914.5), (847.5, 847.75), (960.75, 961.0), (603.5, 603.75), (828.5, 828.75), (811.25, 811.5), (831.25, 831.5), (691.75, 692.0)]
#
# i:
# [ 50.76940842  80.71384668  43.58558429  64.53698789  62.62342326
#   62.15450117  60.08752365  54.5168834   77.35739968  67.61217221]
# i1:
# [  0.          34.91377828   0.          21.0454422   19.67765329
#   19.33336873  22.52002444  17.13283844  42.41613285  33.39615714]
# c:
# [10 16 27 13  9  9 10 17 11 11]
# c1:
# [ 3 69  6 10 43 80 14  5 52 37]
# range:
# 0.25
# 100%
# 2.88s
# 100%
# 3.00s
# 100%
# 2.90s
# 100%
# 3.06s
# 100%
# 2.92s
# 100%
# 3.09s
# 100%
# 2.93s
# 100%
# 3.06s
# 100%
# 3.05s
# 100%
# 3.07s
