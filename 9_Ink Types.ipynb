# %%
# coding: utf-8
import sys
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import time
from numpy import eye
from LoadMZML import LoadMZML
from OptimalMz import OptimalMz
from OptimalMzV2 import OptimalMzV2
from PlotImage import PlotImage
from TemplateOverlay import TemplateOverlay
% matplotlib inline

# %% [markdown]
# # Parameters

# %%
class Parameters:
    def __init__(self):
        #  self.filename = '/Users/simon/Dropbox/MS_Ink_Data/ALphabet/abcdefgh_1.mzML'
        self.filename = '..\\data\\Block2_neg_50.mzML'
        self.lines = 6
        self.widthInMM = 70
        self.heightInMM = 10
        self.downMotionInMM = 1.66

# %%
param = Parameters()
loadMZML = LoadMZML(param)
plotImage = PlotImage(loadMZML, param)

# %%
plotImage.plotImshowII((220.14, 220.16))
# Out:
# 100%
# 11.24s

# %% [markdown]
# # Cell D

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=60, x_stop_mm=70, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=500, resolution=1000)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 233.94s
# i1 - i:
# [ -1.17581848e+08  -4.27431097e+07  -3.40504549e+07  -3.37410853e+07
#   -2.70160582e+07]
#
# mz:
# [(220.0, 220.5), (199.0, 199.5), (157.0, 157.5), (93.0, 93.5), (171.0, 171.5)]
#
# i:
# [ 4074.31370355  1947.02963396  1824.39764158  2419.35711959  1349.63815724]
# i1:
# [  675.60147706   763.00997571   840.16666448  1433.49633635   568.73694854]
# c:
# [ 4665  4715  6603 12171  7090]
# c1:
# [16520 22083 28529 41768 33708]
# range:
# 0.5
# 100%
# 8.79s
# 100%
# 7.92s
# 100%
# 7.88s
# 100%
# 7.98s
# 100%
# 8.27s

# %% [markdown]
# # Cell C

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=41, x_stop_mm=51, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=8000)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 224.46s
# i1 - i:
# [-4724685.64286256 -4603786.67576686 -4354830.74986642 -4103062.15083384
#  -3295286.91661777]
#
# mz:
# [(222.90000000000001, 222.95000000000002), (188.90000000000001, 188.95000000000002), (156.90000000000001, 156.95000000000002), (90.950000000000003, 91.0), (394.80000000000001, 394.85000000000002)]
#
# i:
# [ 386.6162276   383.49634552  337.74319374  354.11512514  290.58977394]
# i1:
# [ 237.49725137  238.19314278  204.81590978  227.47740443  181.74821903]
# c:
# [2898 3066 2780 3448 1705]
# c1:
# [16685 17831 16146 20085  9633]
# range:
# 0.05
# 100%
# 8.47s
# 100%
# 9.44s
# 100%
# 10.33s
# 100%
# 8.27s
# 100%
# 7.89s

# %% [markdown]
# # Cell B

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=400)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 189.68s
# i1 - i:
# [-1638056.00411176 -1509937.71471163 -1338949.43016193  -845047.86410488
#   -688975.39313285]
#
# mz:
# [(220.0, 221.0), (93.0, 94.0), (199.0, 200.0), (157.0, 158.0), (143.0, 144.0)]
#
# i:
# [ 1690.15860562  1751.1958753   1080.32662543  1105.93476115   483.47223414]
# i1:
# [ 1335.90773968  1583.88975733   911.28869712   977.13612312   403.81269048]
# c:
# [3628 7938 3919 5472 4063]
# c1:
# [18001 47635 23952 30690 23579]
# range:
# 1.0
# 100%
# 7.83s
# 100%
# 7.95s
# 100%
# 7.72s
# 100%
# 7.63s
# 100%
# 8.33s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=800)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 186.96s
# i1 - i:
# [-1612677.88547615 -1485168.57144112 -1427310.5462372   -791652.05968843
#   -592627.7640038 ]
#
# mz:
# [(220.0, 220.5), (93.0, 93.5), (199.0, 199.5), (157.0, 157.5), (143.0, 143.5)]
#
# i:
# [ 1722.92319     1796.91577301  1129.9015773   1129.9995643    490.93943747]
# i1:
# [ 1363.67215737  1632.35415844   945.58978156  1006.30392998   414.41209191]
# c:
# [3558 7734 3743 5353 3998]
# c1:
# [17627 46205 23055 29779 22942]
# range:
# 0.5
# 100%
# 7.44s
# 100%
# 7.67s
# 100%
# 7.56s
# 100%
# 7.54s
# 100%
# 9.47s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=1600)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 203.84s
# i1 - i:
# [-1631651.48444005 -1300636.88320874 -1089848.81782979  -788712.0498305
#   -531744.02400366]
#
# mz:
# [(220.0, 220.25), (199.0, 199.25), (93.0, 93.25), (157.0, 157.25), (171.0, 171.25)]
#
# i:
# [ 1777.4143267   1134.03300231  1854.83407448  1135.40987981   797.79563169]
# i1:
# [ 1413.93660684   954.01405654  1717.24427296  1015.19770944   695.22155298]
# c:
# [3447 3729 7490 5327 6019]
# c1:
# [16988 22846 43895 29512 34420]
# range:
# 0.25
# 100%
# 7.50s
# 100%
# 7.62s
# 100%
# 8.60s
# 100%
# 8.76s
# 100%
# 9.04s

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=21, x_stop_mm=30, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=400, resolution=4000)
optimalMz.printN()
for i, j in optimalMz.getN():
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 221.19s
# i1 - i:
# [-2560569.32058402 -1714294.18350543 -1266761.5707217  -1115223.03358939
#  -1098815.82816806]
#
# mz:
# [(157.09999999999999, 157.19999999999999), (220.09999999999999, 220.19999999999999), (199.09999999999999, 199.19999999999999), (143.09999999999999, 143.19999999999999), (93.0, 93.099999999999994)]
#
# i:
# [ 1726.60465065  1821.56249634  1141.44513806   717.36504328  1880.95671381]
# i1:
# [ 1354.91509911  1439.67472991   961.915437     563.00891406  1742.23485695]
# c:
# [3450 3362 3704 2709 7385]
# c1:
# [21854 16678 22653 16773 43259]
# range:
# 0.1
# 100%
# 10.37s
# 100%
# 8.33s
# 100%
# 7.57s
# 100%
# 7.54s
# 100%
# 7.60s

# %% [markdown]
# # Cell A

# %%
optimalMz = OptimalMzV2.V1(loadMZML, x_start_mm=0, x_stop_mm=10, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=1000, resolution=8000)
optimalMz.printN(10)
for i, j in optimalMz.getN(10):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 213.99s
# i1 - i:
# [-127239.81619021  -63487.1161955   -52754.37406007   -8870.69463846
#    -8462.02136895   -4107.87026253   -3624.88159504   -3597.02096481
#    -3353.9565464    -3193.70999583]
#
# mz:
# [(676.0, 676.125), (96.875, 97.0), (169.0, 169.125), (295.0, 295.125), (675.375, 675.5), (237.875, 238.0), (207.375, 207.5), (676.25, 676.375), (675.625, 675.75), (265.0, 265.125)]
#
# i:
# [ 194.80407703   40.55430063  266.47222792   73.28160632   46.4177413
#    52.89519278   40.07945451   33.58238269   35.87842117   30.92838887]
# i1:
# [ 177.1930298    30.63443873  260.23943325   71.47126047   41.3838202
#    51.98009582   38.6858053    32.43537345   34.68441741   22.08154678]
# c:
# [ 1709  2195 15453  2836   635  2539  1970  1200  1165   287]
# c1:
# [ 9626  5156 92371 15480  3883 14927 11698  7250  6806  2326]
# range:
# 0.125
# 100%
# 7.28s
# 100%
# 7.39s
# 100%
# 7.43s
# 100%
# 7.35s
# 100%
# 7.38s
# 100%
# 7.42s
# 100%
# 8.76s
# 100%
# 7.69s
# 100%
# 7.42s
# ...

# %%
optimalMz = OptimalMz.V1(loadMZML, x_start_mm=0, x_stop_mm=10, y_start_mm=0, y_stop_mm=10,
                         mzRangeLower=0, mzRangeHighest=1000, resolution=4000)
optimalMz.printN(10)
for i, j in optimalMz.getN(10):
    plotImage.plotImshowII((i, j))
# Out:
# 100%
# 127.91s
# i1 - i:
# [-45.80006841 -43.49154569 -42.94576997 -42.82113244 -37.56749922
#  -37.38404496 -34.94126683 -34.21601508 -32.95881791 -32.75347141]
#
# mz:
# [(803.75, 804.0), (847.5, 847.75), (960.75, 961.0), (603.5, 603.75), (828.5, 828.75), (811.25, 811.5), (831.25, 831.5), (691.75, 692.0), (963.0, 963.25), (737.75, 738.0)]
#
# i:
# [ 80.71384668  64.53698789  62.62342326  62.15450117  60.08752365
#   54.5168834   77.35739968  67.61217221  67.60215282  66.8948143 ]
# i1:
# [ 34.91377828  21.0454422   19.67765329  19.33336873  22.52002444
#   17.13283844  42.41613285  33.39615714  34.64333491  34.14134289]
# c:
# [16 13  9  9 10 17 11 11  8 10]
# c1:
# [69 10 43 80 14  5 52 37 49 73]
# range:
# 0.25
# 100%
# 7.60s
# 100%
# 7.34s
# 100%
# 7.28s
# 100%
# 7.31s
# 100%
# 7.43s
# 100%
# 7.51s
# 100%
# 8.92s
# 100%
# 8.69s
# 100%
# 8.21s
# 100%
# 8.71s
